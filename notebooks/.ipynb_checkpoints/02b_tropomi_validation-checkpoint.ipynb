# %% [markdown]
# # PipelineWatch-NG — Module 2b: TROPOMI Dry Season Validation
# ### Re-running SO2 analysis for Oct-Dec 2023 (dry season)
#
# **Purpose:** Co-locate SO2 elevation with the 8 DBSCAN fire clusters.
# During the wet season (Jan-Jun), cloud masking blocks most TROPOMI retrievals.
# The dry season (Oct-Dec) gives clean SO2 columns.
#
# **If SO2 > 1.5 DU persists over a fire cluster centroid:**
# That is chemical confirmation of crude oil burning = high-confidence illegal refinery.
#
# ---

# %% [markdown]
# ## Cell 1 — Imports

# %%
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
from IPython.display import Image, display
import ee, os, json, gc
import numpy as np
import pandas as pd
from datetime import datetime

GEE_PROJECT_ID = "pipelinewatch-ng"
CACHE_DIR  = "../data/cached"
OUTPUT_DIR = "../outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

try:
    ee.Initialize(project=GEE_PROJECT_ID)
    print("GEE connected: " + str(ee.Number(42).getInfo()))
except Exception:
    ee.Authenticate()
    ee.Initialize(project=GEE_PROJECT_ID)
print("matplotlib backend: " + matplotlib.get_backend())

# %% [markdown]
# ## Cell 2 — Config

# %%
ROI_BOUNDS = [6.50, 5.00, 7.20, 5.80]
ROI = ee.Geometry.Rectangle(ROI_BOUNDS)

# Dry season window
DRY_START = "2023-10-01"
DRY_END   = "2023-12-31"

# Lowered threshold — smaller operations, cleaner retrievals
SO2_THRESHOLD_DU = 1.5
SO2_MIN_OBS      = 3
BUFFER_KM        = 10  # km radius around each cluster to check for SO2

print("Dry season : " + DRY_START + " to " + DRY_END)
print("SO2 threshold : " + str(SO2_THRESHOLD_DU) + " DU")
print("Search radius : " + str(BUFFER_KM) + " km per cluster")

# %% [markdown]
# ## Cell 3 — Load fire clusters from Module 2

# %%
cluster_path = os.path.join(CACHE_DIR, "m2_refinery_clusters.csv")
if not os.path.exists(cluster_path):
    print("ERROR: run Module 2 first")
else:
    df_clusters = pd.read_csv(cluster_path)
    print("Loaded " + str(len(df_clusters)) + " fire clusters")
    print()
    print(df_clusters[["cluster_id","centroid_lat","centroid_lon",
                        "n_hotspots","max_T21_K","risk_label"]].to_string(index=False))

# %% [markdown]
# ## Cell 4 — TROPOMI dry season composite
#
# Cloud threshold relaxed to 0.4 (from 0.3) to maximise valid dry season retrievals.

# %%
print("Fetching TROPOMI SO2 dry season (" + DRY_START + " to " + DRY_END + ")...")

tropomi_dry = (
    ee.ImageCollection("COPERNICUS/S5P/NRTI/L3_SO2")
    .filterDate(DRY_START, DRY_END)
    .filterBounds(ROI)
    .select(["SO2_column_number_density", "cloud_fraction"])
)

n_images = tropomi_dry.size().getInfo()
print("TROPOMI images found: " + str(n_images))

def mask_and_convert(image):
    cloud  = image.select("cloud_fraction")
    so2_du = (image.select("SO2_column_number_density")
              .multiply(2241.5).rename("SO2_DU"))
    return so2_du.updateMask(cloud.lt(0.4))

clean   = tropomi_dry.map(mask_and_convert)
so2_dry = (
    clean.mean().rename("SO2_mean_DU").clip(ROI)
    .addBands(clean.max().rename("SO2_max_DU").clip(ROI))
    .addBands(clean.count().rename("SO2_obs_count").clip(ROI))
)

gc.collect()
stats = so2_dry.select("SO2_mean_DU").reduceRegion(
    reducer=ee.Reducer.mean()
                      .combine(ee.Reducer.max(), sharedInputs=True)
                      .combine(ee.Reducer.percentile([75,90]), sharedInputs=True),
    geometry=ROI, scale=5500, maxPixels=1e9, bestEffort=True
).getInfo()

print()
print("Dry season SO2 (Dobson Units):")
print("  Mean : " + str(round(stats.get("SO2_mean_DU_mean", 0) or 0, 3)))
print("  p75  : " + str(round(stats.get("SO2_mean_DU_p75",  0) or 0, 3)))
print("  p90  : " + str(round(stats.get("SO2_mean_DU_p90",  0) or 0, 3)))
print("  Max  : " + str(round(stats.get("SO2_mean_DU_max",  0) or 0, 3)))
print("  Threshold: " + str(SO2_THRESHOLD_DU) + " DU")

# %% [markdown]
# ## Cell 5 — Spatial join: SO2 vs fire cluster centroids
#
# For each cluster centroid, sample the mean SO2 within a 10km radius.
# This tells us which clusters have co-located chemical plumes.

# %%
print("Sampling SO2 at each cluster centroid (" + str(BUFFER_KM) + "km radius)...")
print()

results = []
for _, row in df_clusters.iterrows():
    cid  = int(row["cluster_id"])
    pt   = ee.Geometry.Point([row["centroid_lon"], row["centroid_lat"]])
    buf  = pt.buffer(BUFFER_KM * 1000)  # metres

    gc.collect()
    so2_stats = so2_dry.reduceRegion(
        reducer=ee.Reducer.mean().combine(ee.Reducer.max(), sharedInputs=True),
        geometry=buf, scale=5500, maxPixels=1e6, bestEffort=True
    ).getInfo()

    so2_mean = so2_stats.get("SO2_mean_DU_mean", 0) or 0
    so2_max  = so2_stats.get("SO2_max_DU_max",  0) or 0
    obs      = so2_stats.get("SO2_obs_count_mean", 0) or 0

    confirmed = so2_mean >= SO2_THRESHOLD_DU and obs >= SO2_MIN_OBS
    verdict   = "CONFIRMED refinery" if confirmed else "unconfirmed"

    r = {
        "cluster_id":     cid,
        "centroid_lat":   row["centroid_lat"],
        "centroid_lon":   row["centroid_lon"],
        "n_hotspots":     row["n_hotspots"],
        "max_T21_K":      row["max_T21_K"],
        "SO2_mean_DU":    round(so2_mean, 3),
        "SO2_max_DU":     round(so2_max, 3),
        "SO2_obs_count":  round(obs, 1),
        "SO2_confirmed":  confirmed,
        "verdict":        verdict,
    }
    results.append(r)

    flag = " << SO2 CONFIRMED" if confirmed else ""
    print("  C" + str(cid) + ": SO2_mean=" + str(round(so2_mean,3))
          + " DU  SO2_max=" + str(round(so2_max,3))
          + " DU  obs=" + str(round(obs,1)) + flag)

df_validation = pd.DataFrame(results)
n_confirmed   = df_validation["SO2_confirmed"].sum()
print()
print("=" * 50)
print("SO2-confirmed refinery clusters: " + str(n_confirmed) + " / " + str(len(df_clusters)))
print("=" * 50)

# %% [markdown]
# ## Cell 6 — Validation summary chart

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 6))
fig.suptitle("PipelineWatch-NG - TROPOMI Dry Season Validation
"
             "Oct-Dec 2023  |  SO2 co-location with fire clusters", fontsize=12)

# Left: SO2 mean per cluster bar chart
colors = ["#E24B4A" if v else "#B5D4F4" for v in df_validation["SO2_confirmed"]]
x = range(len(df_validation))
axes[0].bar(x, df_validation["SO2_mean_DU"], color=colors, alpha=0.85, width=0.6)
axes[0].axhline(SO2_THRESHOLD_DU, color="#854F0B", linewidth=2,
                linestyle="--", label="Threshold (" + str(SO2_THRESHOLD_DU) + " DU)")
axes[0].set_xticks(x)
axes[0].set_xticklabels(["C" + str(int(i)) for i in df_validation["cluster_id"]])
axes[0].set_ylabel("SO2 mean (Dobson Units)")
axes[0].set_title("SO2 mean per fire cluster
(red = above threshold)")
axes[0].legend(fontsize=9)
axes[0].grid(axis="y", alpha=0.3)
for i, (_, row) in enumerate(df_validation.iterrows()):
    axes[0].text(i, row["SO2_mean_DU"] + 0.02,
                 str(round(row["SO2_mean_DU"], 2)),
                 ha="center", fontsize=8)

# Right: spatial map of clusters coloured by SO2 status
roi_bounds = [6.50, 5.00, 7.20, 5.80]
for _, row in df_validation.iterrows():
    color  = "#E24B4A" if row["SO2_confirmed"] else "#378ADD"
    marker = "*" if row["SO2_confirmed"] else "o"
    size   = 200 if row["SO2_confirmed"] else 80
    axes[1].scatter(row["centroid_lon"], row["centroid_lat"],
                    c=color, marker=marker, s=size, zorder=4,
                    edgecolors="white", linewidths=0.8)
    axes[1].annotate(
        "C" + str(int(row["cluster_id"])) + "
" + str(round(row["SO2_mean_DU"],2)) + "DU",
        xy=(row["centroid_lon"], row["centroid_lat"]),
        xytext=(5, 5), textcoords="offset points", fontsize=7,
        bbox=dict(boxstyle="round,pad=0.2", facecolor="white", alpha=0.7))

axes[1].add_patch(Rectangle((roi_bounds[0], roi_bounds[1]),
    roi_bounds[2]-roi_bounds[0], roi_bounds[3]-roi_bounds[1],
    linewidth=2, edgecolor="#185FA5", facecolor="none", linestyle="--"))

from matplotlib.lines import Line2D
legend_elements = [
    Line2D([0],[0], marker="*", color="w", markerfacecolor="#E24B4A",
           markersize=12, label="SO2 confirmed"),
    Line2D([0],[0], marker="o", color="w", markerfacecolor="#378ADD",
           markersize=8,  label="Unconfirmed"),
]
axes[1].legend(handles=legend_elements, loc="upper right", fontsize=9)
axes[1].set_xlabel("Longitude"); axes[1].set_ylabel("Latitude")
axes[1].set_title("Cluster locations
(* = SO2 confirmed refinery candidate)")
axes[1].grid(alpha=0.3)

plt.tight_layout()
out = os.path.join(OUTPUT_DIR, "m2b_tropomi_validation.png")
plt.savefig(out, dpi=150, bbox_inches="tight")
plt.close()
print("Saved: " + out)
display(Image(out))

# %% [markdown]
# ## Cell 7 — Save validation results

# %%
val_path = os.path.join(CACHE_DIR, "m2b_tropomi_validation.csv")
df_validation.to_csv(val_path, index=False)
print("Validation table saved: " + val_path)
print()
print("=" * 55)
print("TROPOMI DRY SEASON VALIDATION COMPLETE")
print("=" * 55)
print()
print(df_validation[["cluster_id","SO2_mean_DU","SO2_max_DU",
                      "n_hotspots","max_T21_K","SO2_confirmed","verdict"]].to_string(index=False))
print()

if n_confirmed > 0:
    confirmed_ids = df_validation[df_validation["SO2_confirmed"]]["cluster_id"].tolist()
    print("CONFIRMED illegal refinery candidates: Cluster(s) " + str(confirmed_ids))
    print("These clusters show BOTH persistent fire AND SO2 elevation.")
    print("Recommend NNPC field verification at these coordinates:")
    for _, row in df_validation[df_validation["SO2_confirmed"]].iterrows():
        print("  Cluster " + str(int(row["cluster_id"])) + ": "
              + str(round(row["centroid_lat"],4)) + "N, "
              + str(round(row["centroid_lon"],4)) + "E")
else:
    print("No clusters confirmed by SO2 in this window.")
    print("Recommendations:")
    print("  1. Try Nov-Jan window (deepest dry season)")
    print("  2. Lower threshold to 1.0 DU")
    print("  3. Use TROPOMI OFFL (offline) product for better accuracy")

# %% [markdown]
# ## Module 2b complete
#
# | Output | File |
# |--------|------|
# | Validation chart | outputs/m2b_tropomi_validation.png |
# | Validation table | data/cached/m2b_tropomi_validation.csv |
#
# **Interpretation guide:**
# - SO2_confirmed = True AND n_hotspots >= 5 = **high-confidence illegal refinery candidate**
# - SO2_confirmed = True AND n_hotspots < 5 = **possible refinery, needs more fire evidence**
# - SO2_confirmed = False = fire signal only (could be agricultural, flare, or refinery without SO2 plume)
#
# **Next:** Run Module 5 (weekly NRT update) to keep the dashboard current
